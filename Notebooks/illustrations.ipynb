# %%
from unsupervised import *
import random
import numpy
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score,f1_score, recall_score,average_precision_score


SEED = "11"
random.seed(SEED)
np.random.seed(int(SEED))

# %%
g = nx.Graph()
g.add_edges_from(
    [
        (1, 2),
        (1, 5),
        (2, 4),
        (2, 5),
        (4, 5),
        (5, 3),
        (3, 8),
        (3, 7),
        (3, 6),
        (4, 7),
        (4, 8),
        (7, 6),
        (7, 8),
        (6, 8),
        (6, 9),
        
        (10, 13),
        (10, 15),
        (11, 12),
        (11, 14),
        (12, 14),
        (12, 18),
        (12, 21),
        (13, 12),
        (13, 14),
        (13, 18),
        (14, 16),
        (14, 17),
        (14, 18),
        (14, 20),
        (14, 25),
        (15, 18),
        (15, 23),
        (15, 26),
        (16, 17),
        (16, 18),
        (16, 20),
        (17, 18),
        (17, 20),
        (17, 24),
        (18, 19),
        (18, 20),
        (18, 22),
        (18, 24),
        (18, 25),
        (19, 20),
        (19, 21),
        (19, 22),
        (20, 21),
        (20, 22),
        (20, 24),
        (21, 22),
        (21, 24),
        (22, 24),
        (22, 25),
        (23, 24),
        (24, 26),
        
        (3, 19),
        (3, 21),
        (7, 19),
        (7, 21),
        (8, 19),
        (8, 21),
        (8, 22),
        (8, 24),
    ]
)

pos = nx.spring_layout(g)
nx.draw(g, pos)
nx.draw_networkx_nodes(g, pos, nodelist=range(1,10), node_color="b")
nx.draw_networkx_nodes(g, pos, nodelist=range(10,27), node_color="r")
plt.show()
